# %% [markdown]
# <a href="https://colab.research.google.com/github/rameelarustam47/flood-segmentation-swat-valley-unet/blob/main/Unet_flood_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# SWAT FLOOD SEGMENTATION - U-NET FIXED 2025
# ============================================

# STEP 1 - INSTALL AND IMPORT
# !pip install rasterio --quiet
# !pip install imbalanced-learn --quiet

import numpy as np
import matplotlib.pyplot as plt
import rasterio
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print("All libraries imported!")

# STEP 2 - MOUNT DRIVE
from google.colab import drive
drive.mount('/content/drive')

# STEP 3 - SET PATH
path = '/content/drive/MyDrive/swat_flood_2025/'

# STEP 4 - READ ALL FILES
with rasterio.open(path + 'Swat_SAR_Before_2025.tif') as src:
    sar_before = src.read(1).astype(float)
with rasterio.open(path + 'Swat_SAR_During_2025.tif') as src:
    sar_during = src.read(1).astype(float)
with rasterio.open(path + 'Swat_Flood_Extent_Fixed.tif') as src:
    flood_label = src.read(1).astype(float)
with rasterio.open(path + 'Swat_DEM_2025.tif') as src:
    dem = src.read(1).astype(float)
with rasterio.open(path + 'Swat_Slope_2025.tif') as src:
    slope = src.read(1).astype(float)
with rasterio.open(path + 'Swat_Rainfall_CHIRPS_2025.tif') as src:
    rainfall = src.read(1).astype(float)
print("All files loaded!")
print("Original shape:", sar_before.shape)

# STEP 5 - RESIZE TO LARGER SIZE
# Use 512x512 for more patches
target = (512, 512)
sar_before  = resize(sar_before,  target)
sar_during  = resize(sar_during,  target)
flood_label = resize(flood_label, target)
dem         = resize(dem,         target)
slope       = resize(slope,       target)
rainfall    = resize(rainfall,    target)
print("Resized to:", target)

# STEP 6 - NORMALIZE
def normalize(data):
    data = np.nan_to_num(data, nan=0.0)
    if data.max() != data.min():
        return (data - data.min()) / (data.max() - data.min())
    return data

sar_before  = normalize(sar_before)
sar_during  = normalize(sar_during)
dem         = normalize(dem)
slope       = normalize(slope)
rainfall    = normalize(rainfall)
flood_label = (flood_label > 0.5).astype(float)
flood_label = np.nan_to_num(flood_label, nan=0.0)

print("Flood pixels in label:", flood_label.sum())
print("No flood pixels      :", (flood_label==0).sum())
print("Normalization complete!")

# STEP 7 - VISUALIZE DATA
fig, axes = plt.subplots(2, 3, figsize=(16,10))
axes[0,0].imshow(sar_before,  cmap='gray')
axes[0,0].set_title('SAR Before Flood')
axes[0,0].axis('off')
axes[0,1].imshow(sar_during,  cmap='gray')
axes[0,1].set_title('SAR During Flood')
axes[0,1].axis('off')
axes[0,2].imshow(flood_label, cmap='Blues')
axes[0,2].set_title('Flood Label')
axes[0,2].axis('off')
axes[1,0].imshow(dem,         cmap='terrain')
axes[1,0].set_title('DEM')
axes[1,0].axis('off')
axes[1,1].imshow(slope,       cmap='YlOrRd')
axes[1,1].set_title('Slope')
axes[1,1].axis('off')
axes[1,2].imshow(rainfall,    cmap='Blues')
axes[1,2].set_title('Rainfall')
axes[1,2].axis('off')
plt.suptitle('Swat Flood Data 2025', fontsize=16)
plt.tight_layout()
plt.savefig('swat_data_unet.png', dpi=150)
plt.show()

# STEP 8 - CREATE PATCHES WITH SMALLER SIZE
def create_patches(images, label, patch_size=64, stride=16):
    patches_x = []
    patches_y = []
    flood_patches_x = []
    flood_patches_y = []
    h, w = label.shape

    for i in range(0, h - patch_size + 1, stride):
        for j in range(0, w - patch_size + 1, stride):
            patch = np.stack([
                img[i:i+patch_size, j:j+patch_size]
                for img in images
            ], axis=-1)
            label_patch = label[
                i:i+patch_size,
                j:j+patch_size
            ]

            # Separate flood and no flood patches
            if label_patch.sum() > 10:
                flood_patches_x.append(patch)
                flood_patches_y.append(label_patch)
            else:
                patches_x.append(patch)
                patches_y.append(label_patch)

    print(f"Flood patches    : {len(flood_patches_x)}")
    print(f"No flood patches : {len(patches_x)}")

    # Balance patches
    # Use all flood patches
    # Sample equal no flood patches
    n_flood = len(flood_patches_x)
    if n_flood == 0:
        print("WARNING: No flood patches found!")
        print("Using all patches...")
        all_x = patches_x
        all_y = patches_y
    else:
        # Take 3x no flood patches
        import random
        random.seed(42)
        n_noflood = min(n_flood * 3, len(patches_x))
        selected_noflood = random.sample(
            list(zip(patches_x, patches_y)),
            n_noflood
        )
        noflood_x = [p[0] for p in selected_noflood]
        noflood_y = [p[1] for p in selected_noflood]

        all_x = flood_patches_x + noflood_x
        all_y = flood_patches_y + noflood_y

    return np.array(all_x), np.array(all_y)

images = [
    sar_before,
    sar_during,
    dem,
    slope,
    rainfall
]

X_patches, y_patches = create_patches(
    images,
    flood_label,
    patch_size=64,
    stride=16
)

y_patches = np.expand_dims(y_patches, axis=-1)

print("\nTotal patches    :", X_patches.shape[0])
print("Patch shape      :", X_patches.shape[1:])
print("Label shape      :", y_patches.shape[1:])
print("Flood pixels     :", y_patches.sum())

# STEP 9 - SPLIT DATA
X_train, X_test, y_train, y_test = train_test_split(
    X_patches, y_patches,
    test_size=0.2,
    random_state=42
)
print("Train patches:", X_train.shape[0])
print("Test patches :", X_test.shape[0])

# STEP 10 - BUILD U-NET
def unet_model(input_shape=(64, 64, 5)):
    inputs = keras.Input(shape=input_shape)

    # ENCODER
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D(2)(c1)
    p1 = layers.Dropout(0.1)(p1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D(2)(c2)
    p2 = layers.Dropout(0.1)(p2)

    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(64, 3, activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D(2)(c3)
    p3 = layers.Dropout(0.2)(p3)

    # BOTTLENECK
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(128, 3, activation='relu', padding='same')(c4)

    # DECODER
    u5 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(64, 3, activation='relu', padding='same')(u5)
    c5 = layers.Conv2D(64, 3, activation='relu', padding='same')(c5)
    c5 = layers.Dropout(0.2)(c5)

    u6 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(32, 3, activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(32, 3, activation='relu', padding='same')(c6)
    c6 = layers.Dropout(0.1)(c6)

    u7 = layers.Conv2DTranspose(16, 2, strides=2, padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(16, 3, activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(16, 3, activation='relu', padding='same')(c7)
    c7 = layers.Dropout(0.1)(c7)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c7)
    model = keras.Model(inputs, outputs)
    return model

model = unet_model(input_shape=(64, 64, 5))
model.summary()

# STEP 11 - COMPILE WITH WEIGHTED LOSS
def weighted_bce(y_true, y_pred):
    weight = tf.where(
        tf.equal(y_true, 1),
        10.0,
        1.0
    )
    bce = tf.keras.losses.binary_crossentropy(
        y_true, y_pred
    )
    return tf.reduce_mean(bce * tf.squeeze(weight, -1))

model.compile(
    optimizer='adam',
    loss=weighted_bce,
    metrics=[
        'accuracy',
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision()
    ]
)
print("Model compiled with weighted loss!")

# STEP 12 - TRAIN MODEL
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=8,
    validation_split=0.2,
    verbose=1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )
    ]
)
print("Training complete!")

# STEP 13 - PRINT EPOCH RESULTS
print("\nEpoch Results:")
print("-" * 70)
for i in range(len(history.history['accuracy'])):
    print(
        f"Epoch {i+1:2d} | "
        f"Acc: {history.history['accuracy'][i]:.4f} | "
        f"Val Acc: {history.history['val_accuracy'][i]:.4f} | "
        f"Loss: {history.history['loss'][i]:.4f} | "
        f"Val Loss: {history.history['val_loss'][i]:.4f}"
    )

# STEP 14 - PLOT RESULTS
fig, axes = plt.subplots(1, 2, figsize=(14,5))
axes[0].plot(history.history['accuracy'],
             label='Train', color='blue', marker='o')
axes[0].plot(history.history['val_accuracy'],
             label='Validation', color='orange', marker='o')
axes[0].set_title('U-Net Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend()
axes[0].grid(True)
axes[1].plot(history.history['loss'],
             label='Train', color='blue', marker='o')
axes[1].plot(history.history['val_loss'],
             label='Validation', color='orange', marker='o')
axes[1].set_title('U-Net Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend()
axes[1].grid(True)
plt.suptitle('U-Net Training — Swat Flood 2025',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('unet_training_results.png', dpi=150)
plt.show()

# STEP 15 - EVALUATE
results = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy  : {results[1]*100:.2f}%")
print(f"Test Loss      : {results[0]:.4f}")
print(f"Test Recall    : {results[2]:.4f}")
print(f"Test Precision : {results[3]:.4f}")

# STEP 16 - PREDICTIONS
predictions = model.predict(X_test, verbose=0)
pred_binary = (predictions > 0.5).astype(int)

# Show sample predictions
fig, axes = plt.subplots(3, 4, figsize=(16,12))
for i in range(4):
    axes[0,i].imshow(X_test[i,:,:,0], cmap='gray')
    axes[0,i].set_title(f'SAR {i+1}')
    axes[0,i].axis('off')
    axes[1,i].imshow(y_test[i,:,:,0], cmap='Blues')
    axes[1,i].set_title(f'Actual {i+1}')
    axes[1,i].axis('off')
    axes[2,i].imshow(pred_binary[i,:,:,0], cmap='Blues')
    axes[2,i].set_title(f'Predicted {i+1}')
    axes[2,i].axis('off')
plt.suptitle('U-Net Predictions — Swat 2025',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('unet_predictions.png', dpi=150)
plt.show()

# STEP 17 - CONFUSION MATRIX
y_true = y_test.flatten().astype(int)
y_pred = pred_binary.flatten().astype(int)

print("\nUnique values in y_true:", np.unique(y_true))
print("Unique values in y_pred:", np.unique(y_pred))

cm = confusion_matrix(y_true, y_pred, labels=[0,1])
plt.figure(figsize=(8,6))
sns.heatmap(cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['No Flood','Flood'],
    yticklabels=['No Flood','Flood']
)
plt.title('Confusion Matrix — U-Net Swat 2025')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.savefig('unet_confusion_matrix.png', dpi=150)
plt.show()

print("\nClassification Report:")
print(classification_report(
    y_true, y_pred,
    labels=[0,1],
    target_names=['No Flood','Flood']
))

# STEP 18 - FLOOD MAP
print("Creating flood map...")
full_image = np.stack([
    sar_before,
    sar_during,
    dem,
    slope,
    rainfall
], axis=-1)
full_image = np.expand_dims(full_image, axis=0)
flood_map = model.predict(full_image, verbose=0)
flood_map = flood_map[0,:,:,0]

fig, axes = plt.subplots(1, 3, figsize=(18,6))
axes[0].imshow(sar_during, cmap='gray')
axes[0].set_title('SAR During Flood')
axes[0].axis('off')
axes[1].imshow(flood_label, cmap='Blues')
axes[1].set_title('Actual Flood')
axes[1].axis('off')
axes[2].imshow(flood_map, cmap='Blues')
axes[2].set_title('U-Net Predicted')
axes[2].axis('off')
plt.suptitle('Swat Flood Map 2025 — U-Net',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('unet_flood_map.png', dpi=150)
plt.show()

# STEP 19 - SAVE
model.save('swat_unet_model.keras')
print("Model saved!")
print("=" * 40)
print("U-NET COMPLETE!")
print("=" * 40)
from google.colab import files

files.download('swat_data_unet.png')
files.download('unet_training_results.png')
files.download('unet_predictions.png')
files.download('unet_confusion_matrix.png')
files.download('unet_flood_map.png')
# Out:
# All libraries imported!
# Mounted at /content/drive
# All files loaded!
# Original shape: (1857, 1857)
# Resized to: (512, 512)
# Flood pixels in label: 179.0
# No flood pixels      : 261965
# Normalization complete!
# Flood patches    : 83
# No flood patches : 758
#
# Total patches    : 332
# Patch shape      : (64, 64, 5)
# Label shape      : (64, 64, 1)
# Flood pixels     : 2280.0
# Train patches: 265
# Test patches : 67
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 5) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │        736 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32, 32,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 64)  │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 64)  │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 128) │     73,856 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 128) │    147,584 │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │     32,832 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │     73,792 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │     36,928 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_9[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │      8,224 │ dropout_3[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │     18,464 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │      9,248 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_11[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      2,064 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │      4,624 │ concatenate_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │      2,320 │ conv2d_12[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_13[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64, 1) │         17 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 482,321 (1.84 MB)
#  Trainable params: 482,321 (1.84 MB)
#  Non-trainable params: 0 (0.00 B)
# Model compiled with weighted loss!
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 424ms/step - accuracy: 0.9045 - loss: 0.3631 - precision: 0.0015 - recall: 0.0879 - val_accuracy: 0.9982 - val_loss: 0.1464 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 300ms/step - accuracy: 0.9984 - loss: 0.0973 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0762 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 380ms/step - accuracy: 0.9984 - loss: 0.0716 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0715 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 397ms/step - accuracy: 0.9984 - loss: 0.0649 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0670 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 298ms/step - accuracy: 0.9984 - loss: 0.0606 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0641 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 383ms/step - accuracy: 0.9984 - loss: 0.0624 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0673 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 363ms/step - accuracy: 0.9984 - loss: 0.0583 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0601 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 317ms/step - accuracy: 0.9984 - loss: 0.0535 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0584 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 389ms/step - accuracy: 0.9984 - loss: 0.0492 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 317ms/step - accuracy: 0.9984 - loss: 0.0482 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9982 - val_loss: 0.0567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 438ms/step - accuracy: 0.9980 - loss: 0.0444 - precision: 0.1437 - recall: 0.0529 - val_accuracy: 0.9946 - val_loss: 0.0504 - val_precision: 0.0758 - val_recall: 0.1795
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 325ms/step - accuracy: 0.9975 - loss: 0.0419 - precision: 0.1560 - recall: 0.1221 - val_accuracy: 0.9972 - val_loss: 0.0460 - val_precision: 0.1601 - val_recall: 0.1359
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 387ms/step - accuracy: 0.9974 - loss: 0.0375 - precision: 0.2020 - recall: 0.2114 - val_accuracy: 0.9951 - val_loss: 0.0425 - val_precision: 0.1306 - val_recall: 0.3051
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 304ms/step - accuracy: 0.9969 - loss: 0.0356 - precision: 0.2028 - recall: 0.3093 - val_accuracy: 0.9966 - val_loss: 0.0414 - val_precision: 0.2048 - val_recall: 0.3051
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 386ms/step - accuracy: 0.9974 - loss: 0.0324 - precision: 0.2612 - recall: 0.3443 - val_accuracy: 0.9980 - val_loss: 0.0402 - val_precision: 0.4007 - val_recall: 0.2795
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 302ms/step - accuracy: 0.9971 - loss: 0.0321 - precision: 0.2467 - recall: 0.3857 - val_accuracy: 0.9979 - val_loss: 0.0407 - val_precision: 0.3613 - val_recall: 0.2538
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 380ms/step - accuracy: 0.9972 - loss: 0.0285 - precision: 0.2842 - recall: 0.4657 - val_accuracy: 0.9981 - val_loss: 0.0337 - val_precision: 0.4504 - val_recall: 0.3256
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 395ms/step - accuracy: 0.9974 - loss: 0.0254 - precision: 0.3141 - recall: 0.5179 - val_accuracy: 0.9965 - val_loss: 0.0292 - val_precision: 0.2725 - val_recall: 0.5744
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - accuracy: 0.9973 - loss: 0.0246 - precision: 0.3148 - recall: 0.5593 - val_accuracy: 0.9961 - val_loss: 0.0279 - val_precision: 0.2616 - val_recall: 0.6385
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 382ms/step - accuracy: 0.9976 - loss: 0.0213 - precision: 0.3497 - recall: 0.6014 - val_accuracy: 0.9974 - val_loss: 0.0241 - val_precision: 0.3765 - val_recall: 0.6641
# Training complete!
#
# Epoch Results:
# ----------------------------------------------------------------------
# Epoch  1 | Acc: 0.9045 | Val Acc: 0.9982 | Loss: 0.3631 | Val Loss: 0.1464
# Epoch  2 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0973 | Val Loss: 0.0762
# Epoch  3 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0716 | Val Loss: 0.0715
# Epoch  4 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0649 | Val Loss: 0.0670
# Epoch  5 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0606 | Val Loss: 0.0641
# Epoch  6 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0624 | Val Loss: 0.0673
# Epoch  7 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0583 | Val Loss: 0.0601
# Epoch  8 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0535 | Val Loss: 0.0584
# Epoch  9 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0492 | Val Loss: 0.0625
# Epoch 10 | Acc: 0.9984 | Val Acc: 0.9982 | Loss: 0.0482 | Val Loss: 0.0567
# Epoch 11 | Acc: 0.9980 | Val Acc: 0.9946 | Loss: 0.0444 | Val Loss: 0.0504
# Epoch 12 | Acc: 0.9975 | Val Acc: 0.9972 | Loss: 0.0419 | Val Loss: 0.0460
# Epoch 13 | Acc: 0.9974 | Val Acc: 0.9951 | Loss: 0.0375 | Val Loss: 0.0425
# Epoch 14 | Acc: 0.9969 | Val Acc: 0.9966 | Loss: 0.0356 | Val Loss: 0.0414
# Epoch 15 | Acc: 0.9974 | Val Acc: 0.9980 | Loss: 0.0324 | Val Loss: 0.0402
# Epoch 16 | Acc: 0.9971 | Val Acc: 0.9979 | Loss: 0.0321 | Val Loss: 0.0407
# Epoch 17 | Acc: 0.9972 | Val Acc: 0.9981 | Loss: 0.0285 | Val Loss: 0.0337
# Epoch 18 | Acc: 0.9974 | Val Acc: 0.9965 | Loss: 0.0254 | Val Loss: 0.0292
# Epoch 19 | Acc: 0.9973 | Val Acc: 0.9961 | Loss: 0.0246 | Val Loss: 0.0279
# Epoch 20 | Acc: 0.9976 | Val Acc: 0.9974 | Loss: 0.0213 | Val Loss: 0.0241
# Test Accuracy  : 99.74%
# Test Loss      : 0.0265
# Test Recall    : 0.5633
# Test Precision : 0.3575
# Unique values in y_true: [0 1]
# Unique values in y_pred: [0 1]
# Classification Report:
#               precision    recall  f1-score   support
#
#     No Flood       1.00      1.00      1.00    273942
#        Flood       0.36      0.56      0.44       490
#
#     accuracy                           1.00    274432
#    macro avg       0.68      0.78      0.72    274432
# weighted avg       1.00      1.00      1.00    274432
#
# Creating flood map...
# Model saved!
# ========================================
# U-NET COMPLETE!
# ========================================
